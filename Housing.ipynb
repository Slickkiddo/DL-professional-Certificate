# %% [markdown]
# <a href="https://colab.research.google.com/github/Slickkiddo/DL-professional-Certificate/blob/main/Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.3.0

# %%
import keras
import numpy as np

model = keras.Sequential([keras.layers.Dense(units = 1, input_shape =[1])])
model.compile(optimizer="sgd", loss = "mean_squared_error")

xs = np.array([-1.0, 0, 1, 2 , 3, 4], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs,ys,epochs=1000)
print(model.predict([10.0]))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 12.6615
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 10.1885
# Epoch 3/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2381
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6991
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4838
# Epoch 6/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5233
# Epoch 7/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7633
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1612
# Epoch 9/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6833
# Epoch 10/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3034
# Epoch 11/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0005
# Epoch 12/1000
# ...
